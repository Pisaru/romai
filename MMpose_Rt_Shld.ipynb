# %%
# 0. [개인 경로만 입력] ------------------------------------------------------
# 아래 변수만 바꿔서 사용하세요! / Only change this variable for your own path!
MY_PATH = "sample_img/action_video"  # 예: "sample_img/sample_video"

# ---------------------------------------------------------------------------

# 1. Google Drive 마운트 / Google Drive Mount (stable)
from google.colab import drive
drive.flush_and_unmount()  # 기존 마운트 해제 / Unmount previous drive
drive.mount('/content/gdrive', force_remount=True)
import os
os.chdir('/content')  # 작업 디렉토리 고정 / Set working directory

# 2. 필수 패키지 버전 체크 및 필요시 설치 / Check and install required packages
import importlib.util
from packaging import version
from importlib.metadata import version as pkg_version

required = {
    'torch': '2.0.1',
    'torchvision': '0.15.2',
    'torchaudio': '2.0.2',
    'mmcv': '2.0.1',
    'mmdet': '<3.3.0',
    'mmpose': '>=1.1.0',
    'mmengine': None
}

install_needed = False

print("🔍 패키지 버전 확인 중... / Checking package versions...")
for pkg, req_ver in required.items():
    try:
        installed_ver = pkg_version(pkg)
        print(f"✅ {pkg}: {installed_ver}")
        if req_ver:
            if req_ver.startswith(('<', '>', '=')):
                req_spec = version.parse(req_ver.replace('=', '').replace('<', '').replace('>', ''))
                if '<' in req_ver and version.parse(installed_ver) >= req_spec:
                    print(f"❌ {pkg}는 {req_ver} 필요, 현재 {installed_ver} / {pkg} requires {req_ver}, but found {installed_ver}")
                    install_needed = True
                elif '>=' in req_ver and version.parse(installed_ver) < req_spec:
                    print(f"❌ {pkg}는 {req_ver} 필요, 현재 {installed_ver} / {pkg} requires {req_ver}, but found {installed_ver}")
                    install_needed = True
            elif version.parse(installed_ver) != version.parse(req_ver):
                print(f"❌ {pkg}는 {req_ver} 필요, 현재 {installed_ver} / {pkg} requires {req_ver}, but found {installed_ver}")
                install_needed = True
    except:
        print(f"❌ {pkg} 미설치 / {pkg} not installed")
        install_needed = True

if install_needed:
    print("\n🚀 필수 패키지 설치 중... / Installing required packages...")
    # 패키지 설치 / Install commands
    # !pip install torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118
    # !pip uninstall -y jax jaxlib
    # !pip install numpy==1.24.4 pandas==1.5.3 scipy==1.10.1 requests==2.28.2 tqdm==4.65.2 filelock==3.14.0
    # !pip uninstall -y transformers accelerate torchao
    # !pip install transformers==4.30.2
    # !pip install -U openmim
    # !mim uninstall mmengine mmcv mmdet mmpose -y
    # !mim install mmengine
    # !pip install mmcv==2.0.1 -f https://download.openmmlab.com/mmcv/dist/cu118/torch2.0/index.html
    # !mim install "mmdet<3.3.0"
    # !mim install "mmpose>=1.1.0"
    # MMpose 소스 설치 / Install mmpose from source
    # %cd /content
    if not os.path.exists('/content/mmpose'):
        # !git clone https://github.com/open-mmlab/mmpose.git
    # %cd mmpose
    # !pip install -r requirements.txt
    # !pip install -v -e .
    # %cd /content
    print("\n✅ 설치 완료! 런타임을 재시작 후 다시 실행하세요. / Installation completed. Please **RESTART RUNTIME** then run remaining cells!")
else:
    print("\n✅ 모든 패키지가 올바른 버전으로 설치되어 있습니다! / All packages are already installed with correct versions!")

# 3. 작업 폴더 생성 / Create working folders
local_work_root = '/content/work'
local_video_dir = f'{local_work_root}/video'
local_json_dir = f'{local_work_root}/json'
local_vis_dir = f'{local_work_root}/vis'
local_done_vis = f'{local_work_root}/done_vis'
local_done_csv = f'{local_work_root}/done_csv'
local_alljt_vis = f'{local_work_root}/ALL_JT_VIS'
local_alljt_csv = f'{local_work_root}/ALL_JT_CSV'

for d in [local_video_dir, local_json_dir, local_vis_dir, local_done_vis, local_done_csv, local_alljt_vis, local_alljt_csv]:
    os.makedirs(d, exist_ok=True)
# !chmod 777 -R /content/work

# 4. 비디오 복사 (Google Drive → Colab 로컬) / Copy videos from Drive to Colab local
import shutil
drive_video_dir = f'/content/gdrive/MyDrive/{MY_PATH}/'
if os.path.exists(local_video_dir):
    shutil.rmtree(local_video_dir)
os.makedirs(local_video_dir, exist_ok=True)
for fname in os.listdir(drive_video_dir):
    if fname.lower().endswith(('.mp4', '.mov')):
        src = os.path.join(drive_video_dir, fname)
        dst = os.path.join(local_video_dir, fname)
        shutil.copy(src, dst)
        print(f"Copied: {fname} (Google Drive → Colab)")

# 5. MMpose 추론 (직접 Inferencer 호출) / MMpose inference (direct Inferencer call)
print("\n🏃‍♀️ MMpose 추론 시작... / Starting MMpose inference...")
from mmpose.apis import MMPoseInferencer

# 모델 및 체크포인트 경로 설정 (이미 다운로드되었거나 캐시되어 있어야 함)
# MMpose 클론 경로를 사용하여 설정 파일을 지정
mmpose_root = '/content/mmpose' # MMpose가 클론된 경로
pose2d_config = f'{mmpose_root}/configs/body_2d_keypoint/topdown_heatmap/coco/td-hm_hrnet-w32_8xb64-210e_coco-256x192.py'
pose2d_checkpoint = 'https://download.openmmlab.com/mmpose/top_down/hrnet/hrnet_w32_coco_256x192-c78dce93_20200708.pth'

# Inferencer 초기화
try:
    # 수정된 모델 초기화 방식 (직접 URL 대신 모델 alias 사용)
    inferencer = MMPoseInferencer(
        pose2d='td-hm_hrnet-w32_8xb64-210e_coco-256x192',
        device='cpu'  # GPU 가속 사용 / CPU 사용 시 변경
    )
except Exception as e:
    print(f"❌ MMpose Inferencer 초기화 실패: {e}")
    print("MMpose 설치 또는 설정에 문제가 있을 수 있습니다. 런타임 재시작 및 패키지 설치를 다시 확인하세요.")
    inferencer = None # 초기화 실패 시 None으로 설정

video_list = [f for f in os.listdir(local_video_dir) if f.lower().endswith(('.mp4', '.mov'))]

if inferencer:
    for fname in video_list:
        input_path = os.path.join(local_video_dir, fname)
        print(f"처리 중: {fname} / Processing: {fname}")
        try:
            # 추론 실행 및 결과 저장
            # generator를 통해 결과를 얻고, 시각화 및 예측 결과를 저장합니다.
            result_generator = inferencer(input_path,
                                          radius=15,
                                          thickness=8,
                                          pred_out_dir=local_json_dir,
                                          vis_out_dir=local_vis_dir)

            # 결과를 실제로 얻어오기 위해 순회합니다.
            # 이 과정에서 시각화된 비디오 파일과 JSON 파일이 생성됩니다.
            for _ in result_generator:
                pass # generator를 소모하여 파일 생성을 완료합니다.

            print(f"✅ 처리 완료: {fname} / Processed: {fname}")

        except Exception as e:
            print(f"❌ 추론 중 에러 발생 ({fname}): {e} / Error during inference ({fname}): {e}")
            print("해당 비디오 파일 또는 MMpose 설정에 문제가 있을 수 있습니다.")

print("\n✅ MMpose 추론 완료! / MMpose inference completed!")
# 6. Rt.Shoulder 각도만 자막 오버레이 + CSV (done_vis, done_csv)
import cv2
import json
import math
import pandas as pd
import numpy as np

def getAngle(a, b, c):
    # 관절 각도 계산 함수 / Joint angle calculation function
    jt_ang = abs(math.degrees(math.atan2(c[1]-b[1], c[0]-b[0]) - math.atan2(a[1]-b[1], a[0]-b[0])))
    if jt_ang > 180:
        jt_ang = 360 - jt_ang
    return jt_ang

for fname in video_list:
    video_name, ext = os.path.splitext(fname)
    vis_video_path = os.path.join(local_vis_dir, f"{video_name}{ext}")
    json_path = os.path.join(local_json_dir, f"{video_name}.json")
    out_video_path = os.path.join(local_done_vis, f"{video_name}_rt_shld{ext}")
    out_csv_path = os.path.join(local_done_csv, f"{video_name}_rt_shld.csv")
    if not (os.path.exists(vis_video_path) and os.path.exists(json_path)):
        print(f"❌ 파일 없음: {vis_video_path} 또는 {json_path} / Missing file: {vis_video_path} or {json_path}")
        continue

    with open(json_path, 'r') as f:
        json_data = json.load(f)

    cap = cv2.VideoCapture(vis_video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(out_video_path, fourcc, fps, (width, height))

    Rt_SHLD = []
    timestamps = []
    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret or frame_count >= len(json_data):
            break
        try:
            kp = json_data[frame_count]['instances'][0]['keypoints']
            right_shoulder = kp[6][:2]
            right_elbow = kp[8][:2]
            right_hip = kp[12][:2]
            angle = getAngle(right_elbow, right_shoulder, right_hip)
        except Exception:
            angle = 0.0

        Rt_SHLD.append(angle)
        timestamps.append(frame_count / fps)
        # Rt.Shoulder 각도만 상단 왼쪽에 숫자만 표시 / Only number, no 'deg'
        cv2.putText(frame, f"Right Shoulder Angle: {angle:.2f}", (50, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2, cv2.LINE_AA)
        cv2.putText(frame, f"Right Shoulder Angle: {angle:.2f}", (50, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 1, cv2.LINE_AA)
        out.write(frame)
        frame_count += 1

    cap.release()
    out.release()
    pd.DataFrame({'Time (s)': timestamps, 'Right Shoulder Angle': Rt_SHLD}).to_csv(out_csv_path, index=False)
    print(f"✅ 저장됨: {out_video_path}, {out_csv_path} / Saved: {out_video_path}, {out_csv_path}")

# 7. 모든 관절 각도 자막/CSV (상단 여러 줄, 각 관절 위치에 각도값 숫자만)
def put_multiline_subtitle(frame, lines, start_y=40, font_scale=0.8, color=(255,255,255), thickness=2):
    # 여러 줄 자막을 상단에 표시 / Draw multi-line subtitles at the top
    for i, text in enumerate(lines):
        y = start_y + i*35
        cv2.putText(frame, text, (40, y), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0,0,0), thickness+2, cv2.LINE_AA)
        cv2.putText(frame, text, (40, y), cv2.FONT_HERSHEY_SIMPLEX, font_scale, color, thickness, cv2.LINE_AA)

def put_joint_angles(frame, keypoints, joint_angles, angles_dict):
    # 관절 위치에 각도값 숫자만 표시 / Draw only angle number at joint positions
    for i, (name, (a, b, c)) in enumerate(joint_angles):
        x, y = keypoints[b][:2]
        angle = angles_dict[name][-1]
        cv2.circle(frame, (int(x), int(y)), 8, (0, 255, 0), -1)
        text = f"{angle:.1f}"
        cv2.putText(frame, text, (int(x)-20, int(y)-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,0), 2, cv2.LINE_AA)
        cv2.putText(frame, text, (int(x)-20, int(y)-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 1, cv2.LINE_AA)

joint_angles = [
    ("Right Elbow", [6, 8, 10]),
    ("Left Elbow", [5, 7, 9]),
    ("Right Shoulder", [8, 6, 12]),
    ("Left Shoulder", [7, 5, 11]),
    ("Right Knee", [12, 14, 16]),
    ("Left Knee", [11, 13, 15]),
    ("Right Hip", [6, 12, 14]),
    ("Left Hip", [5, 11, 13]),
    ("Neck", [5, 0, 6]),
    ("Waist(L)", [5, 11, 12]),
    ("Waist(R)", [6, 12, 11]),
]

for fname in video_list:
    video_name, ext = os.path.splitext(fname)
    vis_video_path = os.path.join(local_vis_dir, f"{video_name}{ext}")
    json_path = os.path.join(local_json_dir, f"{video_name}.json")
    out_video_path = os.path.join(local_alljt_vis, f"{video_name}_alljt{ext}")
    out_csv_path = os.path.join(local_alljt_csv, f"{video_name}_alljt.csv")
    if not (os.path.exists(vis_video_path) and os.path.exists(json_path)):
        print(f"❌ 파일 없음: {vis_video_path} 또는 {json_path} / Missing file: {vis_video_path} or {json_path}")
        continue

    with open(json_path, 'r') as f:
        json_data = json.load(f)

    cap = cv2.VideoCapture(vis_video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(out_video_path, fourcc, fps, (width, height))

    angle_dict = {name: [] for name, _ in joint_angles}
    timestamps = []
    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret or frame_count >= len(json_data):
            break
        try:
            kp = json_data[frame_count]['instances'][0]['keypoints']
            for name, (a, b, c) in joint_angles:
                angle = getAngle(kp[a][:2], kp[b][:2], kp[c][:2])
                angle_dict[name].append(angle)
            subtitle_lines = []
            for i in range(0, len(joint_angles), 3):
                line = ""
                for j in range(i, min(i+3, len(joint_angles))):
                    name, _ = joint_angles[j]
                    angle = angle_dict[name][-1]
                    line += f"{name}: {angle:.1f}  "
                subtitle_lines.append(line)
            put_multiline_subtitle(frame, subtitle_lines, start_y=40)
            put_joint_angles(frame, kp, joint_angles, angle_dict)
        except Exception as e:
            print(f"Frame {frame_count} error: {e}")
            for name, _ in joint_angles:
                angle_dict[name].append(0.0)
        timestamps.append(frame_count / fps)
        out.write(frame)
        frame_count += 1

    cap.release()
    out.release()
    df = pd.DataFrame({'Time (s)': timestamps})
    for name in angle_dict:
        df[name] = angle_dict[name]
    df.to_csv(out_csv_path, index=False)
    print(f"✅ 저장됨: {out_video_path}, {out_csv_path} / Saved: {out_video_path}, {out_csv_path}")

# 8. 결과를 Google Drive로 복사 / Copy results to Google Drive
def safe_copy(src_pattern, dst_folder):
    import glob
    files = glob.glob(src_pattern)
    if not files:
        print(f"No files to copy: {src_pattern}")
        return
    os.makedirs(dst_folder, exist_ok=True)
    for file in files:
        try:
            shutil.copy(file, dst_folder)
            print(f"✅ 복사됨: {os.path.basename(file)} / Copied: {os.path.basename(file)}")
        except Exception as e:
            print(f"❌ 복사 실패: {str(e)} / Copy failed: {str(e)}")

# 개인 경로에 결과 복사 / Copy to your own path
drive_root = f"/content/gdrive/MyDrive/{MY_PATH}"
safe_copy(f'{local_done_vis}/*', f'{drive_root}/done_vis/')
safe_copy(f'{local_done_csv}/*', f'{drive_root}/done_csv/')
safe_copy(f'{local_alljt_vis}/*', f'{drive_root}/ALL_JT_VIS/')
safe_copy(f'{local_alljt_csv}/*', f'{drive_root}/ALL_JT_CSV/')
safe_copy(f'{local_vis_dir}/*', f'{drive_root}/vis/')
safe_copy(f'{local_json_dir}/*', f'{drive_root}/json/')
# Out:
# Mounted at /content/gdrive
# 🔍 패키지 버전 확인 중... / Checking package versions...
# ✅ torch: 2.0.1+cu118
# ❌ torch는 2.0.1 필요, 현재 2.0.1+cu118 / torch requires 2.0.1, but found 2.0.1+cu118
# ✅ torchvision: 0.15.2+cu118
# ❌ torchvision는 0.15.2 필요, 현재 0.15.2+cu118 / torchvision requires 0.15.2, but found 0.15.2+cu118
# ✅ torchaudio: 2.0.2+cu118
# ❌ torchaudio는 2.0.2 필요, 현재 2.0.2+cu118 / torchaudio requires 2.0.2, but found 2.0.2+cu118
# ✅ mmcv: 2.0.1
# ✅ mmdet: 3.2.0
# ❌ mmpose 미설치 / mmpose not installed
# ✅ mmengine: 0.10.7
#
# 🚀 필수 패키지 설치 중... / Installing required packages...
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.11/dist-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision==0.15.2 in /usr/local/lib/python3.11/dist-packages (0.15.2+cu118)
# Requirement already satisfied: torchaudio==2.0.2 in /usr/local/lib/python3.11/dist-packages (2.0.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (1.24.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.28.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (11.2.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (15.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# WARNING: Skipping jax as it is not installed.
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# WARNING: Skipping jaxlib as it is not installed.
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Requirement already satisfied: numpy==1.24.4 in /usr/local/lib/python3.11/dist-packages (1.24.4)
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.11/dist-packages (1.5.3)
# Requirement already satisfied: scipy==1.10.1 in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Requirement already satisfied: requests==2.28.2 in /usr/local/lib/python3.11/dist-packages (2.28.2)
# Requirement already satisfied: tqdm==4.65.2 in /usr/local/lib/python3.11/dist-packages (4.65.2)
# Requirement already satisfied: filelock==3.14.0 in /usr/local/lib/python3.11/dist-packages (3.14.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.28.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.28.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.28.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.28.2) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.17.0)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# WARNING: Skipping transformers as it is not installed.
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# WARNING: Skipping accelerate as it is not installed.
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# WARNING: Skipping torchao as it is not installed.
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Collecting transformers==4.30.2
#   Using cached transformers-4.30.2-py3-none-any.whl.metadata (113 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (2.28.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (4.65.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.30.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.30.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.30.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.30.2) (2025.4.26)
# Using cached transformers-4.30.2-py3-none-any.whl (7.2 MB)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: transformers
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.15.2 requires accelerate>=0.21.0, which is not installed.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# Successfully installed transformers
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Requirement already satisfied: openmim in /usr/local/lib/python3.11/dist-packages (0.3.9)
# Requirement already satisfied: Click in /usr/local/lib/python3.11/dist-packages (from openmim) (8.2.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in /usr/local/lib/python3.11/dist-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in /usr/local/lib/python3.11/dist-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from openmim) (1.5.3)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.11/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (3.8)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (3.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (4.65.2)
# Requirement already satisfied: openxlab in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (1.24.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.17.0)
# Requirement already satisfied: filelock~=3.14.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (3.14.0)
# Requirement already satisfied: oss2~=2.17.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (24.2)
# Requirement already satisfied: setuptools~=60.2.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (60.2.0)
# Requirement already satisfied: crcmod>=1.7 in /usr/local/lib/python3.11/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.5)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /usr/local/lib/python3.11/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Found existing installation: mmengine 0.10.7
# Uninstalling mmengine-0.10.7:
#   Successfully uninstalled mmengine-0.10.7
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Found existing installation: mmcv 2.0.1
# Uninstalling mmcv-2.0.1:
#   Successfully uninstalled mmcv-2.0.1
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Found existing installation: mmdet 3.2.0
# Uninstalling mmdet-3.2.0:
#   Successfully uninstalled mmdet-3.2.0
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# WARNING: Skipping mmpose as it is not installed.
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmengine
#   Using cached mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from mmengine) (2.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmengine) (1.24.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmengine) (6.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine) (3.1.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from mmengine) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmengine) (4.11.0.86)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine) (2.19.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmengine) (4.3.8)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.17.0)
# Using cached mmengine-0.10.7-py3-none-any.whl (452 kB)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: mmengine
# Successfully installed mmengine-0.10.7
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0/index.html
# Collecting mmcv==2.0.1
#   Using cached https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.0.1-cp311-cp311-manylinux1_x86_64.whl (74.4 MB)
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (0.10.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (1.24.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (11.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (6.0.2)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.0.1) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.0.1) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.0.1) (3.1.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv==2.0.1) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.0.1) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.0.1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (1.17.0)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: mmcv
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Successfully installed mmcv-2.0.1
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmdet<3.3.0
#   Using cached mmdet-3.2.0-py3-none-any.whl.metadata (32 kB)
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# Ignoring mmengine: markers 'extra == "mim"' don't match your environment
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmdet<3.3.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmdet<3.3.0) (1.24.4)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (from mmdet<3.3.0) (2.0.8)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmdet<3.3.0) (1.10.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from mmdet<3.3.0) (2.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from mmdet<3.3.0) (1.17.0)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.11/dist-packages (from mmdet<3.3.0) (3.1.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mmdet<3.3.0) (4.65.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet<3.3.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet<3.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet<3.3.0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet<3.3.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet<3.3.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet<3.3.0) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet<3.3.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmdet<3.3.0) (2.9.0.post0)
# Using cached mmdet-3.2.0-py3-none-any.whl (2.1 MB)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: mmdet
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Successfully installed mmdet-3.2.0
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmpose>=1.1.0
#   Using cached mmpose-1.3.2-py2.py3-none-any.whl.metadata (29 kB)
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# Ignoring mmdet: markers 'extra == "mim"' don't match your environment
# Ignoring mmengine: markers 'extra == "mim"' don't match your environment
# Requirement already satisfied: chumpy in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (0.70)
# Requirement already satisfied: json-tricks in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (3.17.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (3.10.0)
# Requirement already satisfied: munkres in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (1.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (1.24.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (4.11.0.86)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (1.10.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (0.15.2+cu118)
# Requirement already satisfied: xtcocotools>=1.12 in /usr/local/lib/python3.11/dist-packages (from mmpose>=1.1.0) (1.14.3)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.11/dist-packages (from xtcocotools>=1.12->mmpose>=1.1.0) (60.2.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.11/dist-packages (from xtcocotools>=1.12->mmpose>=1.1.0) (3.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose>=1.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose>=1.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose>=1.1.0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose>=1.1.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose>=1.1.0) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose>=1.1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose>=1.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from chumpy->mmpose>=1.1.0) (1.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision->mmpose>=1.1.0) (2.28.2)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.11/dist-packages (from torchvision->mmpose>=1.1.0) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose>=1.1.0) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose>=1.1.0) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose>=1.1.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose>=1.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose>=1.1.0) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose>=1.1.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision->mmpose>=1.1.0) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision->mmpose>=1.1.0) (15.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision->mmpose>=1.1.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision->mmpose>=1.1.0) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision->mmpose>=1.1.0) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision->mmpose>=1.1.0) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1->torchvision->mmpose>=1.1.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1->torchvision->mmpose>=1.1.0) (1.3.0)
# Using cached mmpose-1.3.2-py2.py3-none-any.whl (1.7 MB)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: mmpose
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Successfully installed mmpose
# /content
# /content/mmpose
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements/build.txt (line 2)) (1.24.4)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from -r requirements/build.txt (line 3)) (2.0.1+cu118)
# Requirement already satisfied: chumpy in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 1)) (0.70)
# Requirement already satisfied: json_tricks in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 2)) (3.17.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 3)) (3.10.0)
# Requirement already satisfied: munkres in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 4)) (1.1.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 6)) (4.11.0.86)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 7)) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 8)) (1.10.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 9)) (0.15.2+cu118)
# Requirement already satisfied: xtcocotools>=1.12 in /usr/local/lib/python3.11/dist-packages (from -r requirements/runtime.txt (line 10)) (1.14.3)
# Requirement already satisfied: coverage in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 1)) (7.8.0)
# Requirement already satisfied: flake8 in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 2)) (7.2.0)
# Requirement already satisfied: interrogate in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 3)) (1.7.0)
# Requirement already satisfied: isort==4.3.21 in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 4)) (4.3.21)
# Requirement already satisfied: parameterized in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 5)) (0.9.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 6)) (8.3.5)
# Requirement already satisfied: pytest-runner in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 7)) (6.0.1)
# Requirement already satisfied: xdoctest>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 8)) (1.2.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from -r requirements/tests.txt (line 9)) (0.43.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from -r requirements/optional.txt (line 1)) (2.28.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->-r requirements/build.txt (line 3)) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->-r requirements/build.txt (line 3)) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->-r requirements/build.txt (line 3)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->-r requirements/build.txt (line 3)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->-r requirements/build.txt (line 3)) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->-r requirements/build.txt (line 3)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.8->-r requirements/build.txt (line 3)) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.8->-r requirements/build.txt (line 3)) (15.0.7)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from chumpy->-r requirements/runtime.txt (line 1)) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements/runtime.txt (line 3)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements/runtime.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements/runtime.txt (line 3)) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements/runtime.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements/runtime.txt (line 3)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements/runtime.txt (line 3)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements/runtime.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.11/dist-packages (from xtcocotools>=1.12->-r requirements/runtime.txt (line 10)) (60.2.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.11/dist-packages (from xtcocotools>=1.12->-r requirements/runtime.txt (line 10)) (3.0.12)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from flake8->-r requirements/tests.txt (line 2)) (0.7.0)
# Requirement already satisfied: pycodestyle<2.14.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from flake8->-r requirements/tests.txt (line 2)) (2.13.0)
# Requirement already satisfied: pyflakes<3.4.0,>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from flake8->-r requirements/tests.txt (line 2)) (3.3.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from interrogate->-r requirements/tests.txt (line 3)) (25.3.0)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.11/dist-packages (from interrogate->-r requirements/tests.txt (line 3)) (8.2.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from interrogate->-r requirements/tests.txt (line 3)) (0.4.6)
# Requirement already satisfied: py in /usr/local/lib/python3.11/dist-packages (from interrogate->-r requirements/tests.txt (line 3)) (1.11.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from interrogate->-r requirements/tests.txt (line 3)) (0.9.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->-r requirements/tests.txt (line 6)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->-r requirements/tests.txt (line 6)) (1.5.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->-r requirements/tests.txt (line 9)) (4.3.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements/optional.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements/optional.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements/optional.txt (line 1)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements/optional.txt (line 1)) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->-r requirements/build.txt (line 3)) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.8->-r requirements/build.txt (line 3)) (1.3.0)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Obtaining file:///content/mmpose
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-lys8f518/mmpose.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-lys8f518/mmpose.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-lys8f518/mmpose.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
#   WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
#   WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Collecting xtcocotools@ git+https://github.com/jin-s13/xtcocoapi (from mmpose==1.3.2)
#   Cloning https://github.com/jin-s13/xtcocoapi to /tmp/pip-install-ttxcx07i/xtcocotools_f210d6776cef4fb99a06a9a4a35fa234
#   Running command git version
#   git version 2.34.1
#   Running command git clone --filter=blob:none https://github.com/jin-s13/xtcocoapi /tmp/pip-install-ttxcx07i/xtcocotools_f210d6776cef4fb99a06a9a4a35fa234
#   Cloning into '/tmp/pip-install-ttxcx07i/xtcocotools_f210d6776cef4fb99a06a9a4a35fa234'...
#   Running command git rev-parse HEAD
#   d74033ff1635e9002133b2380862bc2b728584d2
#   Resolved https://github.com/jin-s13/xtcocoapi to commit d74033ff1635e9002133b2380862bc2b728584d2
#   Running command git rev-parse HEAD
#   d74033ff1635e9002133b2380862bc2b728584d2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-kombasiq/xtcocotools.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-kombasiq/xtcocotools.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-kombasiq/xtcocotools.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chumpy in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (0.70)
# Requirement already satisfied: json_tricks in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (3.17.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (3.10.0)
# Requirement already satisfied: munkres in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (1.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (1.24.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (4.11.0.86)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (1.10.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from mmpose==1.3.2) (0.15.2+cu118)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from chumpy->mmpose==1.3.2) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose==1.3.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose==1.3.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose==1.3.2) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose==1.3.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose==1.3.2) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose==1.3.2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmpose==1.3.2) (2.9.0.post0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision->mmpose==1.3.2) (2.28.2)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.11/dist-packages (from torchvision->mmpose==1.3.2) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose==1.3.2) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose==1.3.2) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose==1.3.2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose==1.3.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose==1.3.2) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision->mmpose==1.3.2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision->mmpose==1.3.2) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision->mmpose==1.3.2) (15.0.7)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.11/dist-packages (from xtcocotools@ git+https://github.com/jin-s13/xtcocoapi->mmpose==1.3.2) (60.2.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.11/dist-packages (from xtcocotools@ git+https://github.com/jin-s13/xtcocoapi->mmpose==1.3.2) (3.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision->mmpose==1.3.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision->mmpose==1.3.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision->mmpose==1.3.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision->mmpose==1.3.2) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1->torchvision->mmpose==1.3.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1->torchvision->mmpose==1.3.2) (1.3.0)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: mmpose
#   Running setup.py develop for mmpose
#     Running command python setup.py develop
#     running develop
#     /usr/local/lib/python3.11/dist-packages/setuptools/command/easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     /usr/local/lib/python3.11/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running egg_info
#     writing manifest file 'mmpose.egg-info/SOURCES.txt'
#     running build_ext
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~mpose (/usr/local/lib/python3.11/dist-packages)
# Successfully installed mmpose
# /content
#
# ✅ 설치 완료! 런타임을 재시작 후 다시 실행하세요. / Installation completed. Please **RESTART RUNTIME** then run remaining cells!
# Copied: sport2.mp4 (Google Drive → Colab)
# Copied: sport3.mp4 (Google Drive → Colab)
# Copied: sport1.mp4 (Google Drive → Colab)
# Copied: gait4.mp4 (Google Drive → Colab)
# Copied: gait2.mp4 (Google Drive → Colab)
# Copied: gait1.mp4 (Google Drive → Colab)
# Copied: gait3.mp4 (Google Drive → Colab)
# Copied: sport4.mp4 (Google Drive → Colab)
#
# 🏃‍♀️ MMpose 추론 시작... / Starting MMpose inference...
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/body_2d_keypoint/topdown_heatmap/coco/td-hm_hrnet-w32_8xb64-210e_coco-256x192-81c58e40_20220909.pth
# 05/20 22:50:09 - mmengine - WARNING - Failed to search registry with scope "mmpose" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmpose" is a correct scope, or whether the registry is initialized.
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/rtmdet_m_8xb32-100e_coco-obj365-person-235e8209.pth
# Downloading: "https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/rtmdet_m_8xb32-100e_coco-obj365-person-235e8209.pth" to /root/.cache/torch/hub/checkpoints/rtmdet_m_8xb32-100e_coco-obj365-person-235e8209.pth
# 05/20 22:50:16 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 처리 중: sport3.mp4 / Processing: sport3.mp4
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 05/20 22:58:23 - mmengine - INFO - the output video has been saved at /content/work/vis/sport3.mp4
# ✅ 처리 완료: sport3.mp4 / Processed: sport3.mp4
# 처리 중: gait4.mp4 / Processing: gait4.mp4
# 05/20 23:13:53 - mmengine - INFO - the output video has been saved at /content/work/vis/gait4.mp4
# ✅ 처리 완료: gait4.mp4 / Processed: gait4.mp4
# 처리 중: gait2.mp4 / Processing: gait2.mp4
# 05/20 23:44:16 - mmengine - INFO - the output video has been saved at /content/work/vis/gait2.mp4
# ✅ 처리 완료: gait2.mp4 / Processed: gait2.mp4
# 처리 중: gait3.mp4 / Processing: gait3.mp4
# 05/21 00:17:20 - mmengine - INFO - the output video has been saved at /content/work/vis/gait3.mp4
# ✅ 처리 완료: gait3.mp4 / Processed: gait3.mp4
# 처리 중: sport1.mp4 / Processing: sport1.mp4
# 05/21 00:31:42 - mmengine - INFO - the output video has been saved at /content/work/vis/sport1.mp4
# ✅ 처리 완료: sport1.mp4 / Processed: sport1.mp4
# 처리 중: sport4.mp4 / Processing: sport4.mp4
# 05/21 01:02:02 - mmengine - INFO - the output video has been saved at /content/work/vis/sport4.mp4
# ✅ 처리 완료: sport4.mp4 / Processed: sport4.mp4
# 처리 중: sport2.mp4 / Processing: sport2.mp4
# 05/21 01:13:17 - mmengine - INFO - the output video has been saved at /content/work/vis/sport2.mp4
# ✅ 처리 완료: sport2.mp4 / Processed: sport2.mp4
# 처리 중: gait1.mp4 / Processing: gait1.mp4
# 05/21 01:31:15 - mmengine - INFO - the output video has been saved at /content/work/vis/gait1.mp4
# ✅ 처리 완료: gait1.mp4 / Processed: gait1.mp4
#
# ✅ MMpose 추론 완료! / MMpose inference completed!
# ✅ 저장됨: /content/work/done_vis/sport3_rt_shld.mp4, /content/work/done_csv/sport3_rt_shld.csv / Saved: /content/work/done_vis/sport3_rt_shld.mp4, /content/work/done_csv/sport3_rt_shld.csv
# ✅ 저장됨: /content/work/done_vis/gait4_rt_shld.mp4, /content/work/done_csv/gait4_rt_shld.csv / Saved: /content/work/done_vis/gait4_rt_shld.mp4, /content/work/done_csv/gait4_rt_shld.csv
# ✅ 저장됨: /content/work/done_vis/gait2_rt_shld.mp4, /content/work/done_csv/gait2_rt_shld.csv / Saved: /content/work/done_vis/gait2_rt_shld.mp4, /content/work/done_csv/gait2_rt_shld.csv
# ✅ 저장됨: /content/work/done_vis/gait3_rt_shld.mp4, /content/work/done_csv/gait3_rt_shld.csv / Saved: /content/work/done_vis/gait3_rt_shld.mp4, /content/work/done_csv/gait3_rt_shld.csv
# ✅ 저장됨: /content/work/done_vis/sport1_rt_shld.mp4, /content/work/done_csv/sport1_rt_shld.csv / Saved: /content/work/done_vis/sport1_rt_shld.mp4, /content/work/done_csv/sport1_rt_shld.csv
# ✅ 저장됨: /content/work/done_vis/sport4_rt_shld.mp4, /content/work/done_csv/sport4_rt_shld.csv / Saved: /content/work/done_vis/sport4_rt_shld.mp4, /content/work/done_csv/sport4_rt_shld.csv
# ✅ 저장됨: /content/work/done_vis/sport2_rt_shld.mp4, /content/work/done_csv/sport2_rt_shld.csv / Saved: /content/work/done_vis/sport2_rt_shld.mp4, /content/work/done_csv/sport2_rt_shld.csv
# ✅ 저장됨: /content/work/done_vis/gait1_rt_shld.mp4, /content/work/done_csv/gait1_rt_shld.csv / Saved: /content/work/done_vis/gait1_rt_shld.mp4, /content/work/done_csv/gait1_rt_shld.csv
# ✅ 저장됨: /content/work/ALL_JT_VIS/sport3_alljt.mp4, /content/work/ALL_JT_CSV/sport3_alljt.csv / Saved: /content/work/ALL_JT_VIS/sport3_alljt.mp4, /content/work/ALL_JT_CSV/sport3_alljt.csv
# ✅ 저장됨: /content/work/ALL_JT_VIS/gait4_alljt.mp4, /content/work/ALL_JT_CSV/gait4_alljt.csv / Saved: /content/work/ALL_JT_VIS/gait4_alljt.mp4, /content/work/ALL_JT_CSV/gait4_alljt.csv
# ✅ 저장됨: /content/work/ALL_JT_VIS/gait2_alljt.mp4, /content/work/ALL_JT_CSV/gait2_alljt.csv / Saved: /content/work/ALL_JT_VIS/gait2_alljt.mp4, /content/work/ALL_JT_CSV/gait2_alljt.csv
# ✅ 저장됨: /content/work/ALL_JT_VIS/gait3_alljt.mp4, /content/work/ALL_JT_CSV/gait3_alljt.csv / Saved: /content/work/ALL_JT_VIS/gait3_alljt.mp4, /content/work/ALL_JT_CSV/gait3_alljt.csv
# ✅ 저장됨: /content/work/ALL_JT_VIS/sport1_alljt.mp4, /content/work/ALL_JT_CSV/sport1_alljt.csv / Saved: /content/work/ALL_JT_VIS/sport1_alljt.mp4, /content/work/ALL_JT_CSV/sport1_alljt.csv
# ✅ 저장됨: /content/work/ALL_JT_VIS/sport4_alljt.mp4, /content/work/ALL_JT_CSV/sport4_alljt.csv / Saved: /content/work/ALL_JT_VIS/sport4_alljt.mp4, /content/work/ALL_JT_CSV/sport4_alljt.csv
# ✅ 저장됨: /content/work/ALL_JT_VIS/sport2_alljt.mp4, /content/work/ALL_JT_CSV/sport2_alljt.csv / Saved: /content/work/ALL_JT_VIS/sport2_alljt.mp4, /content/work/ALL_JT_CSV/sport2_alljt.csv
# ✅ 저장됨: /content/work/ALL_JT_VIS/gait1_alljt.mp4, /content/work/ALL_JT_CSV/gait1_alljt.csv / Saved: /content/work/ALL_JT_VIS/gait1_alljt.mp4, /content/work/ALL_JT_CSV/gait1_alljt.csv
# ✅ 복사됨: sport4_rt_shld.mp4 / Copied: sport4_rt_shld.mp4
# ✅ 복사됨: gait2_rt_shld.mp4 / Copied: gait2_rt_shld.mp4
# ✅ 복사됨: sport1_rt_shld.mp4 / Copied: sport1_rt_shld.mp4
# ✅ 복사됨: sport2_rt_shld.mp4 / Copied: sport2_rt_shld.mp4
# ✅ 복사됨: gait3_rt_shld.mp4 / Copied: gait3_rt_shld.mp4
# ✅ 복사됨: gait1_rt_shld.mp4 / Copied: gait1_rt_shld.mp4
# ✅ 복사됨: gait4_rt_shld.mp4 / Copied: gait4_rt_shld.mp4
# ✅ 복사됨: sport3_rt_shld.mp4 / Copied: sport3_rt_shld.mp4
# ✅ 복사됨: sport2_rt_shld.csv / Copied: sport2_rt_shld.csv
# ✅ 복사됨: gait4_rt_shld.csv / Copied: gait4_rt_shld.csv
# ✅ 복사됨: gait2_rt_shld.csv / Copied: gait2_rt_shld.csv
# ✅ 복사됨: sport4_rt_shld.csv / Copied: sport4_rt_shld.csv
# ✅ 복사됨: gait3_rt_shld.csv / Copied: gait3_rt_shld.csv
# ✅ 복사됨: sport1_rt_shld.csv / Copied: sport1_rt_shld.csv
# ✅ 복사됨: gait1_rt_shld.csv / Copied: gait1_rt_shld.csv
# ✅ 복사됨: sport3_rt_shld.csv / Copied: sport3_rt_shld.csv
# ✅ 복사됨: gait2_alljt.mp4 / Copied: gait2_alljt.mp4
# ✅ 복사됨: sport3_alljt.mp4 / Copied: sport3_alljt.mp4
# ✅ 복사됨: gait3_alljt.mp4 / Copied: gait3_alljt.mp4
# ✅ 복사됨: sport4_alljt.mp4 / Copied: sport4_alljt.mp4
# ✅ 복사됨: gait4_alljt.mp4 / Copied: gait4_alljt.mp4
# ✅ 복사됨: sport1_alljt.mp4 / Copied: sport1_alljt.mp4
# ✅ 복사됨: gait1_alljt.mp4 / Copied: gait1_alljt.mp4
# ✅ 복사됨: sport2_alljt.mp4 / Copied: sport2_alljt.mp4
# ✅ 복사됨: gait1_alljt.csv / Copied: gait1_alljt.csv
# ✅ 복사됨: gait4_alljt.csv / Copied: gait4_alljt.csv
# ✅ 복사됨: sport3_alljt.csv / Copied: sport3_alljt.csv
# ✅ 복사됨: sport1_alljt.csv / Copied: sport1_alljt.csv
# ✅ 복사됨: gait3_alljt.csv / Copied: gait3_alljt.csv
# ✅ 복사됨: sport4_alljt.csv / Copied: sport4_alljt.csv
# ✅ 복사됨: gait2_alljt.csv / Copied: gait2_alljt.csv
# ✅ 복사됨: sport2_alljt.csv / Copied: sport2_alljt.csv
# ✅ 복사됨: sport3.mp4 / Copied: sport3.mp4
# ✅ 복사됨: gait4.mp4 / Copied: gait4.mp4
# ✅ 복사됨: gait2.mp4 / Copied: gait2.mp4
# ✅ 복사됨: gait3.mp4 / Copied: gait3.mp4
# ✅ 복사됨: sport1.mp4 / Copied: sport1.mp4
# ✅ 복사됨: sport4.mp4 / Copied: sport4.mp4
# ✅ 복사됨: sport2.mp4 / Copied: sport2.mp4
# ✅ 복사됨: gait1.mp4 / Copied: gait1.mp4
# ✅ 복사됨: sport3.json / Copied: sport3.json
# ✅ 복사됨: sport4.json / Copied: sport4.json
# ✅ 복사됨: sport1.json / Copied: sport1.json
# ✅ 복사됨: gait1.json / Copied: gait1.json
# ✅ 복사됨: sport2.json / Copied: sport2.json
# ✅ 복사됨: gait2.json / Copied: gait2.json
# ✅ 복사됨: gait3.json / Copied: gait3.json
# ✅ 복사됨: gait4.json / Copied: gait4.json
